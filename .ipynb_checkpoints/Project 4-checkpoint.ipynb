# %%
#age : age in years
#sex: (1 = male; 0 = female)
#cp: chest pain type
#trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#chol: serum cholestoral in mg/dl
#fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#restecg: resting electrocardiographic results
#thalach : maximum heart rate achieved
#exang: exercise induced angina (1 = yes; 0 = no)
#oldpeak: ST depression induced by exercise relative to rest
#slope: the slope of the peak exercise ST segment
#ca: number of major vessels (0-3) colored by flourosopy
#thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#num : target 1 or 0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from scipy import stats
import seaborn as sns

# %%
clevDT = pd.read_csv('cleveland.csv')
clevDT.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
clevDT.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
clevDT.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
#for i in range(0,clevDT.shape[1]):
    #print(clevDT.columns.values[i],clevDT[clevDT.columns.values[i]].unique())
print(clevDT.ca.value_counts())
print(clevDT.thal.value_counts())
# Out:
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# ?        4
# Name: ca, dtype: int64
# 3.0    166
# 7.0    117
# 6.0     18
# ?        2
# Name: thal, dtype: int64

# %%
print(clevDT.ca.value_counts())
print(clevDT.thal.value_counts())
clevDT = clevDT[(clevDT.ca !='?') & (clevDT.thal !='?') ]
print(clevDT.ca.value_counts())
print(clevDT.thal.value_counts())
#clevDT[['ca','thal']] = clevDT[['ca','thal']].replace('[?]','0.0',regex=True)
clevDT = clevDT.astype('float64')
print(clevDT.ca.unique())
print(clevDT.thal.unique())
# Out:
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# ?        4
# Name: ca, dtype: int64
# 3.0    166
# 7.0    117
# 6.0     18
# ?        2
# Name: thal, dtype: int64
# 0.0    174
# 1.0     65
# 2.0     38
# 3.0     20
# Name: ca, dtype: int64
# 3.0    164
# 7.0    115
# 6.0     18
# Name: thal, dtype: int64
# [0. 3. 2. 1.]
# [6. 3. 7.]

# %%
clevDT.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# num         float64
# dtype: object

# %%
X =clevDT.iloc[:,:-1] # This dataset takes all the columns except num
Y = clevDT.iloc[:,-1] # This dataset contains a=only num series
tempDT = pd.get_dummies(data=X,columns=['cp','restecg','slope','ca','thal'])
ClevDTNew = pd.concat([tempDT,Y],axis=1)
ClevDTNew.head()
ClevDTNew.corr()['num'].sort_value()
# Out:
# age            0.222156
# sex            0.226797
# trestbps       0.159620
# chol           0.066448
# fbs            0.049040
# thalach       -0.420639
# exang          0.391613
# oldpeak        0.501461
# cp_1.0        -0.109985
# cp_2.0        -0.238184
# cp_3.0        -0.277180
# cp_4.0         0.484832
# restecg_0.0   -0.197149
# restecg_1.0    0.123610
# restecg_2.0    0.168667
# slope_1.0     -0.402480
# slope_2.0      0.341863
# slope_3.0      0.118633
# ca_0.0        -0.480447
# ca_1.0         0.142068
# ca_2.0         0.311174
# ca_3.0         0.295173
# thal_3.0      -0.511833
# thal_6.0       0.102698
# thal_7.0       0.472201
# num            1.000000
# Name: num, dtype: float64

# %%
plt.figure(figsize=(16,16))
sns.heatmap(ClevDTNew.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
print(ClevDTNew.shape[1])
ClevDTNew.drop(columns=['thalach','cp_1.0','cp_2.0','cp_3.0','restecg_0.0','slope_1.0','ca_0.0','thal_3.0'],inplace=True)
#ClevDTNew = ClevDTNew[['age','sex','trestbps','exang','oldpeak','cp_4.0','restecg_1.0','restecg_2.0','slope_2.0','slope_3.0','ca_2.0','ca_3.0',
                            #'thal_6.0','thal_7.0','num']]
print(ClevDTNew.shape[1])
print()
# Out:
# 26
# 18

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.neighbors import NearestNeighbors,KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import warnings
warnings.filterwarnings('ignore') 
X= ClevDTNew.iloc[:,:-1].values
Y= ClevDTNew.iloc[:,-1].values

# Model Parameters Declaration

knn= NearestNeighbors(n_neighbors=10,metric='euclidean',p=2,algorithm='auto')
print(knn)
nn= KNeighborsClassifier()
pca=PCA(n_components=2)
sc=StandardScaler()
minMax= MinMaxScaler(feature_range=(0,1))
#End

X=pca.fit_transform(X)
#X=minMax.fit_transform(X)
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
#print(X_train.shape)
#display(X)
acc_List=pd.Series()

cvList=pd.Series()
for i in range(80,120):
    nn= KNeighborsClassifier(n_neighbors=i,metric='euclidean',p=2,algorithm='auto',weights='distance')
    cvList=cvList.append(pd.Series(i))
    accuracies= cross_val_score(estimator= nn,X=X_train,y=y_train,cv=i,scoring="accuracy")
    acc_List=acc_List.append(pd.Series(accuracies.mean()))
#display(pd.concat([cvList,acc_List],axis=1))
#cv=24,k=40,acc=60%
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=5, p=2, radius=1.0)

# %%
ax=plt.figure(figsize=(16,6))
ax=sns.lineplot(x=cvList,y=acc_List)
ax=sns.scatterplot(x=cvList,y=acc_List,color='red',linewidth=15)
ax.set_ylabel('accuracy_rate',fontsize=15)
ax.set_xlabel('Cross_Validation_CV_No',fontsize=15)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
params=dict(n_neighbors=[98,123,101,153,107],
            algorithm=['auto','ball_tree','kd_tree','brute'],leaf_size=[30,35,45,47,50],
            metric=['minkowski','euclidean','manhattan'],p=[1,2])
grid = GridSearchCV(estimator=nn,param_grid=params,cv=10,scoring='accuracy')
grid.fit(X_train,y_train)
print(grid.best_score_,grid.best_params_)
# Out:
# 0.5147679324894515 {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'n_neighbors': 153, 'p': 1}

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import f1_score,precision_recall_fscore_support,accuracy_score
import warnings
warnings.filterwarnings('ignore') 
X= ClevDTNew.iloc[:,:-1].values
Y= ClevDTNew.iloc[:,-1].values

# Model Parameters Declaration


sc=StandardScaler()
minMax= MinMaxScaler(feature_range=(0,1))
pca=PCA(n_components=7)
#End
X=pca.fit_transform(X)
#X = sc.fit_transform(X)

X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=69)
fitData= knn.fit(X_train,y_train)
for i in range(10,40):
    knn= NearestNeighbors(metric='euclidean',p=2,algorithm='auto',n_neighbors=i,radius=0.5)
    distance,indices = fitData.kneighbors(X_train)
    #print(indices.shape)
    y_train_Pred=[]
    for each in indices:
        list_Of_Y_train_val = [y_train[elem] for elem in each]
        #print(pd.Series(list_Of_Y_train_val).value_counts(),'kkkkk',stats.mode(list_Of_Y_train_val)[0][0])
        y_train_Pred.append(stats.mode(list_Of_Y_train_val)[0][0])
    #print(y_train.shape,len(y_Pred))
    #print('train_data:',i,f1_score(y_train_Pred,y_train,average='weighted'))
#display(X_test)
#fitData= knn.fit(X_test,y_test)
for i in range(40,80):
    #X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=i)
    #print(X_test)
    knn= NearestNeighbors(metric='euclidean',p=2,algorithm='auto',n_neighbors=i,radius=0.2)
    distance,indices = fitData.kneighbors(X_test)
    #print(indices)
    y_Pred=[]
    for each in indices:
        list_Of_Y_test_val = [Y[elem] for elem in each]
        y_Pred.append(stats.mode(list_Of_Y_test_val)[0][0])
    (p,r,f,s) = precision_recall_fscore_support(y_test, y_Pred)
    acc_score = accuracy_score(y_test, y_Pred)
    #print(y_train.shape,len(y_Pred))
    print(i,'f1_score:',f1_score(y_Pred,y_test,average='weighted'),'accuracy: ',acc_score)
# Out:
# 40 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 41 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 42 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 43 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 44 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 45 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 46 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 47 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 48 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 49 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 50 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 51 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 52 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 53 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 54 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 55 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 56 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 57 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 58 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 59 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 60 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 61 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 62 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 63 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 64 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 65 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 66 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 67 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 68 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 69 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 70 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 71 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 72 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 73 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 74 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 75 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 76 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 77 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 78 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333
# 79 f1_score: 0.8118811881188119 accuracy:  0.6833333333333333

# %%
0.2,69,84
# Out:
# (0.2, 69, 84)
